# %%
#Importing Needed Packages
import pandas as pd
import numpy as np
import sklearn
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.feature_selection import RFE
from sklearn import preprocessing
# %matplotlib inline

# %%
#Reading CSV file as weatheather_df
weather_df = pd.read_csv("assesment 2 data set.csv" , na_values = "?" , encoding = 'latin-1')
weather_df.head(5)
# Out:
#         Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0  1/01/2020                      18.9                      27.3
# 1  2/01/2020                      19.3                      29.0
# 2  3/01/2020                      21.9                      29.4
# 3  4/01/2020                      20.9                      36.4
# 4  5/01/2020                      21.4                      26.6
#
#    Rainfall (mm)  Evaporation (mm)  Sunshine (hours)  \
# 0            0.0              14.2               4.5
# 1            0.0               7.2               5.3
# 2            0.0               NaN               8.2
# 3            0.0              15.4              10.5
# 4            0.0              16.0               4.4
#
#   Direction of maximum wind gust   Speed of maximum wind gust (km/h)  \
# 0                             SSW                               39.0
# 1                             SSW                               35.0
# ...

# %%
#Checking   Columns In DataFrame
weather_df.columns
# Out:
# Index(['Date', 'Minimum temperature (°C)', 'Maximum temperature (°C)',
#        'Rainfall (mm)', 'Evaporation (mm)', 'Sunshine (hours)',
#        'Direction of maximum wind gust ', 'Speed of maximum wind gust (km/h)',
#        'Time of maximum wind gust', '9am Temperature (°C)',
#        '9am relative humidity (%)', '9am cloud amount (oktas)',
#        '9am wind direction', '9am wind speed (km/h)', '9am MSL pressure (hPa)',
#        '3pm Temperature (°C)', '3pm relative humidity (%)',
#        '3pm cloud amount (oktas)', '3pm wind direction',
#        '3pm wind speed (km/h)', '3pm MSL pressure (hPa)'],
#       dtype='object')

# %%
#Checking number of rowsa and columns of the data

#computing number of rows 
rows = len(weather_df.axes[0])

#computing number of columns
cols = len(weather_df.axes[1])

#Printing number of rows and columns 
print("Number of Rows: ", rows)
print("Number of Columns: ", cols)
# Out:
# Number of Rows:  366
# Number of Columns:  21

# %%
# Statistical summary of our data
weather_df.describe()
# Out:
#        Minimum temperature (°C)  Maximum temperature (°C)  Rainfall (mm)  \
# count                366.000000                364.000000     362.000000
# mean                  14.670219                 23.510714       4.285083
# std                    4.354354                  4.786657      13.519783
# min                    6.200000                 13.600000       0.000000
# 25%                   10.900000                 19.700000       0.000000
# 50%                   14.800000                 23.400000       0.000000
# 75%                   18.275000                 26.500000       2.550000
# max                   25.300000                 41.200000     164.800000
#
#        Evaporation (mm)  Sunshine (hours)  Speed of maximum wind gust (km/h)  \
# count        356.000000        362.000000                         365.000000
# mean           5.382865          6.525414                          42.663014
# std            3.317315          4.020979                          14.720617
# ...

# %%
# Checking for the NaN values in the data
weather_df.isna().sum()
# Out:
# Date                                  0
# Minimum temperature (°C)              0
# Maximum temperature (°C)              2
# Rainfall (mm)                         4
# Evaporation (mm)                     10
# Sunshine (hours)                      4
# Direction of maximum wind gust        1
# Speed of maximum wind gust (km/h)     1
# Time of maximum wind gust             1
# 9am Temperature (°C)                  0
# 9am relative humidity (%)             1
# 9am cloud amount (oktas)              1
# 9am wind direction                    0
# 9am wind speed (km/h)                 0
# 9am MSL pressure (hPa)                0
# 3pm Temperature (°C)                  2
# 3pm relative humidity (%)             2
# 3pm cloud amount (oktas)              1
# 3pm wind direction                    0
# 3pm wind speed (km/h)                 0
# 3pm MSL pressure (hPa)                0
# dtype: int64

# %%
#Cleaning our data by deopping nan values and checking the shape of our data 
weather_df.dropna(inplace=True)
print("Shape after dropping NaN rows:", weather_df.shape)
# Out:
# Shape after dropping NaN rows: (345, 21)

# %%
#Shape of our new dataframe
weather_df.shape
# Out:
# (345, 21)

# %%
#Re-checking if there is any nan value
weather_df.isnull().any()
# Out:
# Date                                 False
# Minimum temperature (°C)             False
# Maximum temperature (°C)             False
# Rainfall (mm)                        False
# Evaporation (mm)                     False
# Sunshine (hours)                     False
# Direction of maximum wind gust       False
# Speed of maximum wind gust (km/h)    False
# Time of maximum wind gust            False
# 9am Temperature (°C)                 False
# 9am relative humidity (%)            False
# 9am cloud amount (oktas)             False
# 9am wind direction                   False
# 9am wind speed (km/h)                False
# 9am MSL pressure (hPa)               False
# 3pm Temperature (°C)                 False
# 3pm relative humidity (%)            False
# 3pm cloud amount (oktas)             False
# 3pm wind direction                   False
# 3pm wind speed (km/h)                False
# 3pm MSL pressure (hPa)               False
# dtype: bool

# %%
#Now let's select maximum temperature to be the target variable, which will be predicted from rest of the features. 
#weather_x stores the rest of the dataset while weather_y has  temperature column 

weather = weather_df.loc[:, [
       'Minimum temperature (°C)',
       'Maximum temperature (°C)', 
       'Rainfall (mm)',
       'Evaporation (mm)',
       'Sunshine (hours)',
       '9am Temperature (°C)',
       '9am relative humidity (%)',
       '9am cloud amount (oktas)',
       #'9am wind speed (km/h)',
       '3pm Temperature (°C)', 
       '3pm relative humidity (%)',
       '3pm cloud amount (oktas)',
       #'3pm wind speed (km/h)' 
        ]]
weather.head()
# Out:
#    Minimum temperature (°C)  Maximum temperature (°C)  Rainfall (mm)  \
# 0                      18.9                      27.3            0.0
# 1                      19.3                      29.0            0.0
# 3                      20.9                      36.4            0.0
# 4                      21.4                      26.6            0.0
# 5                      19.4                      27.9            0.0
#
#    Evaporation (mm)  Sunshine (hours)  9am Temperature (°C)  \
# 0              14.2               4.5                  20.9
# 1               7.2               5.3                  22.6
# 3              15.4              10.5                  26.6
# 4              16.0               4.4                  22.5
# 5               8.4               0.2                  21.8
#
#    9am relative humidity (%)  9am cloud amount (oktas)  3pm Temperature (°C)  \
# 0                       68.0                       8.0                  24.9
# ...

# %%
#shape of new dataframe
weather.shape
# Out:
# (345, 11)

# %%
weather.tail()
# Out:
#      Minimum temperature (°C)  Maximum temperature (°C)  Rainfall (mm)  \
# 361                      17.3                      27.4            3.6
# 362                      19.3                      30.3            0.0
# 363                      16.9                      20.8           14.0
# 364                      17.2                      24.0           19.2
# 365                      18.3                      24.5            0.2
#
#      Evaporation (mm)  Sunshine (hours)  9am Temperature (°C)  \
# 361               6.6              11.7                  19.4
# 362               7.4               4.2                  26.2
# 363               6.0               0.0                  17.3
# 364               1.6               2.8                  18.9
# 365               7.4               0.5                  22.1
#
#      9am relative humidity (%)  9am cloud amount (oktas)  \
# 361                       93.0                       1.0
# ...

# %%
#columns in our new dataframe
weather.columns
# Out:
# Index(['Minimum temperature (°C)', 'Maximum temperature (°C)', 'Rainfall (mm)',
#        'Evaporation (mm)', 'Sunshine (hours)', '9am Temperature (°C)',
#        '9am relative humidity (%)', '9am cloud amount (oktas)',
#        '3pm Temperature (°C)', '3pm relative humidity (%)',
#        '3pm cloud amount (oktas)'],
#       dtype='object')

# %%
#ploting all column values
weather.plot(subplots=True, figsize=(25,20))
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
#in histogram 
weather.hist(bins=10,figsize=(15,15))
# Out:
# array([[<Axes: title={'center': 'Minimum temperature (°C)'}>,
#         <Axes: title={'center': 'Maximum temperature (°C)'}>,
#         <Axes: title={'center': 'Rainfall (mm)'}>],
#        [<Axes: title={'center': 'Evaporation (mm)'}>,
#         <Axes: title={'center': 'Sunshine (hours)'}>,
#         <Axes: title={'center': '9am Temperature (°C)'}>],
#        [<Axes: title={'center': '9am relative humidity (%)'}>,
#         <Axes: title={'center': '9am cloud amount (oktas)'}>,
#         <Axes: title={'center': '3pm Temperature (°C)'}>],
#        [<Axes: title={'center': '3pm relative humidity (%)'}>,
#         <Axes: title={'center': '3pm cloud amount (oktas)'}>, <Axes: >]],
#       dtype=object)

# %%
weather.head()
# Out:
#    Minimum temperature (°C)  Maximum temperature (°C)  Rainfall (mm)  \
# 0                      18.9                      27.3            0.0
# 1                      19.3                      29.0            0.0
# 3                      20.9                      36.4            0.0
# 4                      21.4                      26.6            0.0
# 5                      19.4                      27.9            0.0
#
#    Evaporation (mm)  Sunshine (hours)  9am Temperature (°C)  \
# 0              14.2               4.5                  20.9
# 1               7.2               5.3                  22.6
# 3              15.4              10.5                  26.6
# 4              16.0               4.4                  22.5
# 5               8.4               0.2                  21.8
#
#    9am relative humidity (%)  9am cloud amount (oktas)  3pm Temperature (°C)  \
# 0                       68.0                       8.0                  24.9
# ...

# %%
type(weather)
# Out:
# pandas.core.frame.DataFrame

# %%
# weather.dropna(inplace=True)
# print("Shape of weather:", weather.shape)
# print("Columns in weather:", weather.columns)

# %%
weather
# Out:
#      Minimum temperature (°C)  Maximum temperature (°C)  Rainfall (mm)  \
# 0                        18.9                      27.3            0.0
# 1                        19.3                      29.0            0.0
# 3                        20.9                      36.4            0.0
# 4                        21.4                      26.6            0.0
# 5                        19.4                      27.9            0.0
# ..                        ...                       ...            ...
# 361                      17.3                      27.4            3.6
# 362                      19.3                      30.3            0.0
# 363                      16.9                      20.8           14.0
# 364                      17.2                      24.0           19.2
# 365                      18.3                      24.5            0.2
#
#      Evaporation (mm)  Sunshine (hours)  9am Temperature (°C)  \
# ...

# %%
weather_x = weather[['Evaporation (mm)',
       'Minimum temperature (°C)', 
       'Rainfall (mm)',
       'Sunshine (hours)',
       '9am Temperature (°C)',
       '9am relative humidity (%)',
       '9am cloud amount (oktas)',
       '3pm Temperature (°C)', 
       '3pm relative humidity (%)',
       '3pm cloud amount (oktas)',]]
weather_y = weather['Maximum temperature (°C)']

# %%
#now our data is prepared and it is ready to be fed to the model for training it's time to split the dataset into training and testing 
train_x,test_x, train_y, test_y = train_test_split(weather_x,weather_y, test_size=0.2, random_state=4)

# %%
print(train_x.shape)
print(test_x.shape)
print(train_y.shape)
print(test_y.shape)
# Out:
# (276, 10)
# (69, 10)
# (276,)
# (69,)

# %%
train_x
# Out:
#      Evaporation (mm)  Minimum temperature (°C)  Rainfall (mm)  \
# 169               1.2                      11.8            3.2
# 287               7.8                      16.7            0.0
# 237               4.0                       6.2            0.0
# 259               4.8                      14.0            0.0
# 51                7.0                      19.7            0.0
# ..                ...                       ...            ...
# 327               4.4                      20.7            2.6
# 93                1.8                      17.5            4.8
# 214               2.6                       7.2            0.0
# 190               0.8                       8.5            0.0
# 135               3.8                       9.7            3.4
#
#      Sunshine (hours)  9am Temperature (°C)  9am relative humidity (%)  \
# 169               4.7                  13.3                       87.0
# ...

# %%
type(train_x)
# Out:
# pandas.core.frame.DataFrame

# %%
train_y.shape
# Out:
# (276,)

# %%
#train_x has all the features except max temperature and train_y has the corresponding temperature for those features. in supervised machine learning we first feed the model with 
#input and associated output and then we check with a new input
train_y.head()
# Out:
# 169    19.9
# 287    23.5
# 237    18.9
# 259    24.2
# 51     26.6
# Name: Maximum temperature (°C), dtype: float64

# %%
train_x.shape
train_x.head()
# Out:
#      Evaporation (mm)  Minimum temperature (°C)  Rainfall (mm)  \
# 169               1.2                      11.8            3.2
# 287               7.8                      16.7            0.0
# 237               4.0                       6.2            0.0
# 259               4.8                      14.0            0.0
# 51                7.0                      19.7            0.0
#
#      Sunshine (hours)  9am Temperature (°C)  9am relative humidity (%)  \
# 169               4.7                  13.3                       87.0
# 287              11.2                  18.7                       73.0
# 237              10.7                  10.7                       56.0
# 259              10.8                  18.8                       80.0
# 51                6.8                  21.9                       72.0
#
#      9am cloud amount (oktas)  3pm Temperature (°C)  \
# 169                       7.0                  17.2
# ...

# %%
# Multiple Linear Regression
plt.scatter(weather.loc[:, 'Minimum temperature (°C)'], weather.loc[:, 'Maximum temperature (°C)'])
plt.xlabel("Minimum Temperature")
plt.ylabel("Maximum Temperature")
plt.show()

# %%
plt.scatter(weather.loc[:, 'Rainfall (mm)'], weather.loc[:, 'Maximum temperature (°C)'])
plt.xlabel("Rainfall(mm)")
plt.ylabel("Maximum Temperature")
plt.show()

# %%
plt.scatter(weather.loc[:, 'Evaporation (mm)'], weather.loc[:, 'Maximum temperature (°C)'])
plt.xlabel("Evaporation(mm)")
plt.ylabel("Maximum Temperature")
plt.show()

# %%
plt.scatter(weather.loc[:, 'Sunshine (hours)'], weather.loc[:, 'Maximum temperature (°C)'])
plt.xlabel("Sunshine(hours)")
plt.ylabel("Maximum Temperature")
plt.show()

# %%
print(train_x.dtypes)
# Out:
# Evaporation (mm)             float64
# Minimum temperature (°C)     float64
# Rainfall (mm)                float64
# Sunshine (hours)             float64
# 9am Temperature (°C)         float64
# 9am relative humidity (%)    float64
# 9am cloud amount (oktas)     float64
# 3pm Temperature (°C)         float64
# 3pm relative humidity (%)    float64
# 3pm cloud amount (oktas)     float64
# dtype: object

# %%
model=LinearRegression()
model.fit(train_x,train_y)
# Out:
# LinearRegression()

# %%
prediction = model.predict(test_x)

# %%
#calculating error
np.mean(np.absolute(prediction-test_y))
# Out:
# 0.6777779523339597

# %%
print('Variance score: %.2f' % model.score(test_x, test_y))
# Out:
# Variance score: 0.95

# %%
for i in range(len(prediction)):
  prediction[i]=round(prediction[i],2)
pd.DataFrame({'Actual':test_y,'Prediction':prediction,'diff':(test_y-prediction)})
# Out:
#      Actual  Prediction  diff
# 69     23.6       24.68 -1.08
# 36     24.4       25.29 -0.89
# 202    17.4       17.61 -0.21
# 159    17.3       17.20  0.10
# 143    17.7       17.48  0.22
# ..      ...         ...   ...
# 279    19.8       20.67 -0.87
# 307    23.9       24.71 -0.81
# 271    20.2       21.07 -0.87
# 35     27.4       27.91 -0.51
# 340    30.7       30.56  0.14
#
# [69 rows x 3 columns]

# %%
from sklearn.metrics import r2_score
print("Mean absolute error: %.2f" % np.mean(np.absolute(prediction - test_y)))
print("Residual sum of squares (MSE): %.2f" % np.mean((prediction - test_y) ** 2))
print("R2-score: %.2f" % r2_score(test_y,prediction ) )
# Out:
# Mean absolute error: 0.68
# Residual sum of squares (MSE): 0.72
# R2-score: 0.95
